# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = sns.load_dataset(name='iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# finding p
data_2=data[['sepal_length','sepal_width','petal_length','petal_width']]
p=data_2.values
print("Sample data:")
print(p)
# Out:
# Sample data:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
# ...

# %%
l_mean=[]
for k in range(len(p[0])):
  c=0
  for j in range(len(p)):
    c=c+p[j][k]/len(p)
  l_mean.append(c)

# %%
l_variance=[]
for k in range(len(p[0])):
  c=0
  for j in range(len(p)):
    c=c+((p[j][k]-l_mean[k])**2)/len(p)
  l_variance.append(c)

# %%
# Step 1: Normalization
normal=[]
for k in range(len(p)):
  temp=[]
  for j in range(len(p[0])):
    temp.append((p[k][j]-l_mean[j])/((l_variance[j])**(1/2)))
  normal.append(temp)
normal=np.array(normal)
print("Normalized point")
print(normal)
# Out:
# Normalized point
# [[-9.00681170e-01  1.01900435e+00 -1.34022653e+00 -1.31544430e+00]
#  [-1.14301691e+00 -1.31979479e-01 -1.34022653e+00 -1.31544430e+00]
#  [-1.38535265e+00  3.28414053e-01 -1.39706395e+00 -1.31544430e+00]
#  [-1.50652052e+00  9.82172869e-02 -1.28338910e+00 -1.31544430e+00]
#  [-1.02184904e+00  1.24920112e+00 -1.34022653e+00 -1.31544430e+00]
#  [-5.37177559e-01  1.93979142e+00 -1.16971425e+00 -1.05217993e+00]
#  [-1.50652052e+00  7.88807586e-01 -1.34022653e+00 -1.18381211e+00]
#  [-1.02184904e+00  7.88807586e-01 -1.28338910e+00 -1.31544430e+00]
#  [-1.74885626e+00 -3.62176246e-01 -1.34022653e+00 -1.31544430e+00]
#  [-1.14301691e+00  9.82172869e-02 -1.28338910e+00 -1.44707648e+00]
#  [-5.37177559e-01  1.47939788e+00 -1.28338910e+00 -1.31544430e+00]
#  [-1.26418478e+00  7.88807586e-01 -1.22655167e+00 -1.31544430e+00]
#  [-1.26418478e+00 -1.31979479e-01 -1.34022653e+00 -1.44707648e+00]
#  [-1.87002413e+00 -1.31979479e-01 -1.51073881e+00 -1.44707648e+00]
# ...

# %%
l_mean_2=[]
for k in range(len(normal[0])):
  c=0
  for j in range(len(normal)):
    c=c+normal[j][k]/len(normal)
  l_mean_2.append(c)

l_variance_2=[]
for k in range(len(normal[0])):
  c=0
  for j in range(len(normal)):
    c=c+((normal[j][k]-l_mean_2[k])**2)/len(normal)
  l_variance_2.append(c)

# %%
# Step-2: Compute the Covariance matrix
cov=[]
for k in range(len(normal[0])):
  temp=[]
  for j in range(len(normal[0])):
    c=0
    for i in range(len(normal)):
      c=c+(normal[i][k]-l_mean_2[k])*(normal[i][j]-l_mean_2[j])/len(normal)
    temp.append(c)
  cov.append(temp)
cov=np.array(cov)
print(cov)
# Out:
# [[ 1.         -0.11756978  0.87175378  0.81794113]
#  [-0.11756978  1.         -0.4284401  -0.36612593]
#  [ 0.87175378 -0.4284401   1.          0.96286543]
#  [ 0.81794113 -0.36612593  0.96286543  1.        ]]

# %%
# step-3: Compute the eigen values and the eigen vectors

eigen=np.linalg.eig(cov)
eigen_values=eigen.eigenvalues
eigen_vectors=eigen.eigenvectors
print(eigen_values)
print(eigen_vectors)
# Out:
# [2.91849782 0.91403047 0.14675688 0.02071484]
# [[ 0.52106591 -0.37741762 -0.71956635  0.26128628]
#  [-0.26934744 -0.92329566  0.24438178 -0.12350962]
#  [ 0.5804131  -0.02449161  0.14212637 -0.80144925]
#  [ 0.56485654 -0.06694199  0.63427274  0.52359713]]

# %%
print("PCA:")
for k in range(len(eigen_values)):
  print(f"PCA {k+1}:",eigen_vectors[:,k])
# Out:
# PCA:
# PCA 1: [ 0.52106591 -0.26934744  0.5804131   0.56485654]
# PCA 2: [-0.37741762 -0.92329566 -0.02449161 -0.06694199]
# PCA 3: [-0.71956635  0.24438178  0.14212637  0.63427274]
# PCA 4: [ 0.26128628 -0.12350962 -0.80144925  0.52359713]

# %%
# step-4: dimensionality reduction to 2D
d_2=eigen_vectors[:,:2]

mul_2=[]
for k in range(len(normal)):
  temp=[]
  for j in range(len(d_2[0])):
    c=0
    for i in range(len(normal[0])):
      c=c+normal[k][i]*d_2[i][j]
    temp.append(c)
  mul_2.append(temp)
mul_2=np.array(mul_2)
print("2D dimension reduction")
print(mul_2)
# Out:
# 2D dimension reduction
# [[-2.26470281 -0.4800266 ]
#  [-2.08096115  0.67413356]
#  [-2.36422905  0.34190802]
#  [-2.29938422  0.59739451]
#  [-2.38984217 -0.64683538]
#  [-2.07563095 -1.48917752]
#  [-2.44402884 -0.0476442 ]
#  [-2.23284716 -0.22314807]
#  [-2.33464048  1.11532768]
#  [-2.18432817  0.46901356]
#  [-2.1663101  -1.04369065]
#  [-2.32613087 -0.13307834]
#  [-2.2184509   0.72867617]
#  [-2.6331007   0.96150673]
#  [-2.1987406  -1.86005711]
#  [-2.26221453 -2.68628449]
#  [-2.2075877  -1.48360936]
#  [-2.19034951 -0.48883832]
#  [-1.898572   -1.40501879]
#  [-2.34336905 -1.12784938]
#  [-1.914323   -0.40885571]
#  [-2.20701284 -0.92412143]
#  [-2.7743447  -0.45834367]
#  [-1.81866953 -0.08555853]
#  [-2.22716331 -0.13725446]
#  [-1.95184633  0.62561859]
#  [-2.05115137 -0.24216355]
#  [-2.16857717 -0.52714953]
#  [-2.13956345 -0.31321781]
#  [-2.26526149  0.3377319 ]
#  [-2.14012214  0.50454069]
#  [-1.83159477 -0.42369507]
#  [-2.61494794 -1.79357586]
# ...

# %%
# step-4: dimensionality reduction to 3D
d_3=eigen_vectors[:,:3]

mul_3=[]
for k in range(len(normal)):
  temp=[]
  for j in range(len(d_3[0])):
    c=0
    for i in range(len(normal[0])):
      c=c+normal[k][i]*d_3[i][j]
    temp.append(c)
  mul_3.append(temp)
mul_3=np.array(mul_3)
print("3D dimension reduction")
print(mul_3)
# Out:
# 3D dimension reduction
# [[-2.26470281 -0.4800266  -0.12770602]
#  [-2.08096115  0.67413356 -0.23460885]
#  [-2.36422905  0.34190802  0.04420148]
#  [-2.29938422  0.59739451  0.09129011]
#  [-2.38984217 -0.64683538  0.0157382 ]
#  [-2.07563095 -1.48917752  0.02696829]
#  [-2.44402884 -0.0476442   0.3354704 ]
#  [-2.23284716 -0.22314807 -0.0886955 ]
#  [-2.33464048  1.11532768  0.14507686]
#  [-2.18432817  0.46901356 -0.25376557]
#  [-2.1663101  -1.04369065 -0.2686811 ]
#  [-2.32613087 -0.13307834  0.09375924]
#  [-2.2184509   0.72867617 -0.23091124]
#  [-2.6331007   0.96150673  0.18079608]
#  [-2.1987406  -1.86005711 -0.472901  ]
#  [-2.26221453 -2.68628449  0.03052661]
#  [-2.2075877  -1.48360936 -0.00534409]
#  [-2.19034951 -0.48883832 -0.04421532]
#  [-1.898572   -1.40501879 -0.37434327]
#  [-2.34336905 -1.12784938  0.13263047]
#  [-1.914323   -0.40885571 -0.42129259]
#  [-2.20701284 -0.92412143  0.15986528]
#  [-2.7743447  -0.45834367  0.3321791 ]
# ...

# %%
color=['blue','red','green']
label=['setosa','versicolor','virginica']
x=[]
y=[]
for k in range(len(mul_2)):
  x.append(mul_2[k][0])
  y.append(mul_2[k][1])
for k in range(3):
  plt.scatter(x=x[50*k:50*(k+1)],y=y[50*k:50*(k+1)],color=color[k],label=label[k])
plt.title("2D dimentional reduction")
plt.xlabel("Principle componenet 1")
plt.ylabel("Principle componenet 2")
plt.legend()
plt.show()

# %%
color=['blue','red','green']
label=['setosa','versicolor','virginica']
x=[]
y=[]
z=[]
for k in range(len(mul_3)):
  x.append(mul_3[k][0])
  y.append(mul_3[k][1])
  z.append(mul_3[k][2])
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
for k in range(3):
  ax.scatter(xs=x[50*k:50*(k+1)],ys=y[50*k:50*(k+1)],zs=z[50*k:50*(k+1)],color=color[k],label=label[k])
ax.set_title("3D dimentional reduction")
ax.set_xlabel("Principle componenet 1")
ax.set_ylabel("Principle componenet 2")
ax.set_zlabel("Principle componenet 3")
ax.legend()
plt.show()
